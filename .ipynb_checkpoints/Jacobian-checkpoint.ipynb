# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

# %%
mydata = pd.read_csv('stpsf-data/WFI/wim_zernikes_cycle9.csv', sep=',', header=0)
print(mydata.values)
# Out:
# [[ 1.00000e+00  4.80000e-01  1.00000e+00 ...  5.50217e-03 -9.46813e-03
#    4.25296e-03]
#  [ 1.00000e+00  4.80000e-01  2.00000e+00 ...  5.94724e-03 -9.23025e-03
#    2.63345e-03]
#  [ 1.00000e+00  4.80000e-01  3.00000e+00 ...  6.37167e-03 -9.13213e-03
#    2.42618e-03]
#  ...
#  [ 1.80000e+01  2.30000e+00  3.00000e+00 ...  1.38555e-03 -1.68853e-03
#    3.14048e-04]
#  [ 1.80000e+01  2.30000e+00  4.00000e+00 ...  1.19143e-03 -2.00779e-03
#    4.95551e-04]
#  [ 1.80000e+01  2.30000e+00  5.00000e+00 ...  1.38649e-03 -1.88375e-03
#    3.41620e-04]]

# %%
wavelength = mydata['wavelength']
mask1 = np.where(wavelength == 0.48)
mask2 = np.where(wavelength == 0.62)

# %%
mask1
# Out:
# (array([   0,    1,    2,    3,    4,  105,  106,  107,  108,  109,  210,
#          211,  212,  213,  214,  315,  316,  317,  318,  319,  420,  421,
#          422,  423,  424,  525,  526,  527,  528,  529,  630,  631,  632,
#          633,  634,  735,  736,  737,  738,  739,  840,  841,  842,  843,
#          844,  945,  946,  947,  948,  949, 1050, 1051, 1052, 1053, 1054,
#         1155, 1156, 1157, 1158, 1159, 1260, 1261, 1262, 1263, 1264, 1365,
#         1366, 1367, 1368, 1369, 1470, 1471, 1472, 1473, 1474, 1575, 1576,
#         1577, 1578, 1579, 1680, 1681, 1682, 1683, 1684, 1785, 1786, 1787,
#         1788, 1789]),)

# %%
localAngleX = mydata['axis_local_angle_x']
localAngleY = mydata['axis_local_angle_y']
globalX = mydata['global_x']
globalY = mydata['global_y']
#sca = mydata['sca']

# %%
localAngleXArray = np.array(localAngleX)[mask1]
localAngleYArray = np.array(localAngleY)[mask1]
globalXArray = np.array(globalX)[mask1]
globalYArray = np.array(globalY)[mask1]

# %%
angleInput = np.dstack((localAngleXArray, localAngleYArray))
poly = PolynomialFeatures(degree=4)
angleInput_ = poly.fit_transform(angleInput[0])
modelX = linear_model.LinearRegression()
modelY = linear_model.LinearRegression()
modelX.fit(angleInput_, globalXArray)
modelY.fit(angleInput_, globalYArray)
# Out:
# LinearRegression()

# %%
poly.powers_
# Out:
# array([[0, 0],
#        [1, 0],
#        [0, 1],
#        [2, 0],
#        [1, 1],
#        [0, 2],
#        [3, 0],
#        [2, 1],
#        [1, 2],
#        [0, 3],
#        [4, 0],
#        [3, 1],
#        [2, 2],
#        [1, 3],
#        [0, 4]])

# %%
poly.powers_[:,0]
# Out:
# array([0, 1, 0, 2, 1, 0, 3, 2, 1, 0, 4, 3, 2, 1, 0])

# %%
modelX.coef_
# Out:
# array([ 0.00000000e+00,  3.26517163e+02, -7.91139524e-02, -1.44166674e-01,
#         1.52538813e+01,  9.54352387e-03,  1.57610407e+01, -3.94184908e-02,
#         1.64559167e+01,  1.14887060e-02,  2.68675768e-02,  1.66020231e+00,
#        -8.68491438e-02,  1.13539168e+00, -3.71086055e-01])

# %%
modelY.coef_
# Out:
# array([ 0.00000000e+00, -3.89361265e-04, -3.33968073e+02, -7.61333266e+00,
#         1.27156584e-01, -2.32051981e+01,  1.02788877e-03, -1.64045687e+01,
#         4.04509362e-02, -1.69721904e+01, -3.23316881e-01,  5.82181852e-02,
#        -2.13256150e+00, -2.44781926e-01, -2.58474827e+00])

# %%
localAngleXArray = np.array(localAngleX)[mask2]
localAngleYArray = np.array(localAngleY)[mask2]
globalXArray = np.array(globalX)[mask2]
globalYArray = np.array(globalY)[mask2]

# %%
angleInput = np.dstack((localAngleXArray, localAngleYArray))
poly = PolynomialFeatures(degree=4)
angleInput_ = poly.fit_transform(angleInput[0])
modelX = linear_model.LinearRegression()
modelY = linear_model.LinearRegression()
modelX.fit(angleInput_, globalXArray)
modelY.fit(angleInput_, globalYArray)
# Out:
# LinearRegression()

# %%
modelX.coef_
# Out:
# array([ 0.00000000e+00,  3.26524734e+02, -7.93184474e-02, -1.42533388e-01,
#         1.52540161e+01,  9.15045326e-03,  1.57607648e+01, -4.32651975e-02,
#         1.64564495e+01,  2.66899516e-02,  2.06440395e-02,  1.66743464e+00,
#        -9.07515177e-02,  1.11796961e+00, -4.09524478e-01])

# %%
modelY.coef_
# Out:
# array([ 0.00000000e+00, -4.01049469e-04, -3.33975734e+02, -7.61300133e+00,
#         1.27326689e-01, -2.32048132e+01,  9.74243612e-04, -1.64039459e+01,
#         4.12584128e-02, -1.69687836e+01, -3.28836010e-01,  5.75633969e-02,
#        -2.11400026e+00, -2.46064702e-01, -2.62018071e+00])

# %%
def computeJacobian(wavelength, polyorder = 4):
    #Read Input csv from STSCi Files 
    mydata = pd.read_csv('stpsf-data/WFI/wim_zernikes_cycle9.csv', sep=',', header=0)

    #Define mask to desired wavelength
    mask1 = np.where(mydata['wavelength']==wavelength)

    #Read columns from csv
    localAngleX = mydata['axis_local_angle_x']
    localAngleY = mydata['axis_local_angle_y']
    globalX = mydata['global_x']
    globalY = mydata['global_y']

    #Mask columns at desired wavelength
    localAngleXArray = np.array(localAngleX)[mask1]
    localAngleYArray = np.array(localAngleY)[mask1]
    globalXArray = np.array(globalX)[mask1]
    globalYArray = np.array(globalY)[mask1]

    
    #Sklearn multivariable polynomial fit
    angleInput = np.dstack((localAngleXArray, localAngleYArray))
    poly = PolynomialFeatures(degree=polyorder)
    angleInput_ = poly.fit_transform(angleInput[0])
    modelX = linear_model.LinearRegression()
    modelY = linear_model.LinearRegression()
    modelX.fit(angleInput_, globalXArray)
    modelY.fit(angleInput_, globalYArray)

    coefX = modelX.coef_
    coefY = modelY.coef_
    xpowers = poly.powers_[:,0]
    ypowers = poly.powers_[:,1]
    newpowersx = np.clip(xpowers-1,0,None)
    newpowersy = np.clip(ypowers-1,0,None)

    newpolyorder = np.empty((2,2), dtype = object)
    newpolyorder[0][0] = np.stack((newpowersx,ypowers), axis = 1)
    newpolyorder[0][1] = np.stack((xpowers,newpowersy), axis = 1)
    newpolyorder[1][0] = np.stack((newpowersx,ypowers), axis = 1)
    newpolyorder[1][1] = np.stack((xpowers,newpowersy), axis = 1)

    jacob = np.empty((2,2), dtype = object)
    jacob[0][0] = xpowers*coefX
    jacob[0][1] = ypowers*coefX
    jacob[1][0] = xpowers*coefY
    jacob[1][1] = ypowers*coefY
    
    return jacob, newpolyorder

# %%
computeJacobian(0.48)
# Out:
# (array([[array([ 0.00000000e+00,  3.26517163e+02, -0.00000000e+00, -2.88333349e-01,
#                  1.52538813e+01,  0.00000000e+00,  4.72831221e+01, -7.88369815e-02,
#                  1.64559167e+01,  0.00000000e+00,  1.07470307e-01,  4.98060692e+00,
#                 -1.73698288e-01,  1.13539168e+00, -0.00000000e+00])                ,
#          array([ 0.00000000e+00,  0.00000000e+00, -7.91139524e-02, -0.00000000e+00,
#                  1.52538813e+01,  1.90870477e-02,  0.00000000e+00, -3.94184908e-02,
#                  3.29118334e+01,  3.44661181e-02,  0.00000000e+00,  1.66020231e+00,
#                 -1.73698288e-01,  3.40617505e+00, -1.48434422e+00])                ],
#         [array([ 0.00000000e+00, -3.89361265e-04, -0.00000000e+00, -1.52266653e+01,
#                  1.27156584e-01, -0.00000000e+00,  3.08366630e-03, -3.28091373e+01,
#                  4.04509362e-02, -0.00000000e+00, -1.29326753e+00,  1.74654556e-01,
#                 -4.26512301e+00, -2.44781926e-01, -0.00000000e+00])                ,
#          array([ 0.00000000e+00, -0.00000000e+00, -3.33968073e+02, -0.00000000e+00,
#                  1.27156584e-01, -4.64103961e+01,  0.00000000e+00, -1.64045687e+01,
#                  8.09018724e-02, -5.09165713e+01, -0.00000000e+00,  5.82181852e-02,
#                 -4.26512301e+00, -7.34345778e-01, -1.03389931e+01])                ]],
#        dtype=object),
#  array([[array([[0, 0],
#                 [0, 0],
#                 [0, 1],
#                 [1, 0],
#                 [0, 1],
#                 [0, 2],
#                 [2, 0],
#                 [1, 1],
#                 [0, 2],
#                 [0, 3],
#                 [3, 0],
#                 [2, 1],
#                 [1, 2],
#                 [0, 3],
#                 [0, 4]]), array([[0, 0],
#                                  [1, 0],
#                                  [0, 0],
#                                  [2, 0],
#                                  [1, 0],
#                                  [0, 1],
#                                  [3, 0],
#                                  [2, 0],
#                                  [1, 1],
#                                  [0, 2],
#                                  [4, 0],
#                                  [3, 0],
#                                  [2, 1],
#                                  [1, 2],
#                                  [0, 3]])],
#         [array([[0, 0],
#                 [0, 0],
#                 [0, 1],
#                 [1, 0],
#                 [0, 1],
#                 [0, 2],
#                 [2, 0],
#                 [1, 1],
#                 [0, 2],
#                 [0, 3],
#                 [3, 0],
#                 [2, 1],
#                 [1, 2],
#                 [0, 3],
#                 [0, 4]]), array([[0, 0],
#                                  [1, 0],
#                                  [0, 0],
#                                  [2, 0],
#                                  [1, 0],
#                                  [0, 1],
#                                  [3, 0],
#                                  [2, 0],
#                                  [1, 1],
#                                  [0, 2],
#                                  [4, 0],
#                                  [3, 0],
#                                  [2, 1],
#                                  [1, 2],
#                                  [0, 3]])]], dtype=object))
